# %%
import boto3

s3 = boto3.client("s3")

bucket_name = "your-bucket-name"
prefix = "data/"   # folder name

response = s3.list_objects_v2(
    Bucket=bucket_name,
    Prefix=prefix
)

if "Contents" in response:
    for obj in response["Contents"]:
        print(obj["Key"])
